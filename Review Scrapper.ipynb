# %%
from flask import Flask,request,jsonify

# %%
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as urReq

# %%
flipkart_url='https://www.flipkart.com/search?q='+'iphone11'

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone11'

# %%
responser_web=urReq(flipkart_url)

# %%
flipkart_data=responser_web.read()

# %%
flipkart_data ### This is the source code
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
bs(flipkart_data,"html.parser") ## Modification to source tfro easy understand
# Out:
# <!DOCTYPE html>
# ...

# %%
beautify_html=bs(flipkart_data,"html.parser")

# %%
beautify_html.find_all('div',{"class":"_1AtVbE col-12-12"})
# Out:
# [<div class="_1AtVbE col-12-12" style="padding:0px 0px 10px 0px"><div><a class="_3WcRHs _2VGJMH" href="/mobiles/~cs-81hziz7kkm/pr?sid=tyy%2C4io&amp;collection-tab-name=iPhone+14+and+14+Plus&amp;param=987935"><div class="_3ywSr_" style="padding-top:25.18%"><div class="_1bEAQy _312yBx" style="padding-top:25.18%"><img alt="A" class="_2OHU_q"/><img alt="A" class="kJjFO0 _3DIhEh" src="https://rukminim1.flixcart.com/fk-p-flap/100/100/image/0c8ad7fd48489ad9.jpg?q=50"/></div></div></a></div></div>,
# ...

# %%
len(beautify_html.find_all('div',{"class":"_1AtVbE col-12-12"}))  ## 31 div tag are there
# Out:
# 31

# %%
big_box=beautify_html.find_all('div',{"class":"_1AtVbE col-12-12"})

# %%
big_box[3]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBFWQ6BVWVEH3XE" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&amp;lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&amp;marketplace=FLIPKART&amp;q=iphone11&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=3f19abc0-36fa-428c-ae55-f0f3569a2b50.MOBFWQ6BVWVEH3XE.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=g36ecacds00000001673091926888&amp;qH=d6db477051465f9a" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 11 (White, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/k2jbyq80pkrrdj/mobile-refurbished/k/y/d/iphone-11-256-u-mwm82hn-a-apple-0-original-imafkg25mhaztxns.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDk
# ...

# %%
big_box[3].div.div.div.a['href']
# Out:
# '/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=3f19abc0-36fa-428c-ae55-f0f3569a2b50.MOBFWQ6BVWVEH3XE.SEARCH&ppt=None&ppn=None&ssid=g36ecacds00000001673091926888&qH=d6db477051465f9a'

# %%
filpkart_url+big_box[3].div.div.div.a['href']
# Out:
# 'https://www.flipkart.com/search?q=apple11/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=3f19abc0-36fa-428c-ae55-f0f3569a2b50.MOBFWQ6BVWVEH3XE.SEARCH&ppt=None&ppn=None&ssid=g36ecacds00000001673091926888&qH=d6db477051465f9a'

# %%
product3=filpkart_url+big_box[3].div.div.div.a['href']

# %%
import requests

# %%
requests.get(product3)
# Out:
# <Response [200]>

# %%
product=requests.get(product3)

# %%
product.encoding='utf-8'

# %%
bs(product.text,'html.parser') ##return all source code at more presentable form
# Out:
# <!DOCTYPE html>
# ...

# %%
product3_page=bs(product.text,'html.parser')

# %%
product3_page.find_all('div',{"class":"_16PBlm"})
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Simply awesome</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202011/blobio-imr-202011_e4b34b9e355e4836ade8b1f6345ee73b.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Flipkart Customer</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path 
# ...

# %%
all_review=product3_page.find_all('div',{"class":"_16PBlm"})

# %%
len(all_review) ### total 11 review there
# Out:
# 11

# %%
all_review[5]
# Out:
# <div class="_16PBlm _3_IKGE"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Worth every penny</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Previously I was using one plus 3t it was a great phone <br/>And then I decided to upgrade I am stuck between Samsung s10 plus or iPhone 11 <br/>I have seen the specs and everything were good except the display it’s somewhere between 720-1080 and it’s not even an amoled it’s an LCD display <br/>But I decided to go with iPhone because I have never used an IOS device I have Been an android user from the past 9 years I ordered IPhone 11 (128gb) product red<br/>My experience after using 3 weeks <br/>1. The delivery ...</div><span class="_1BWGvX"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202001/bl
# ...

# %%
### Lets extract comment box

# %%
all_review[5].div.div.div.div.text ### text as rating in text file
# Out:
# '5'

# %%
rating=all_review[5].div.div.div.div.text

# %%
## lets check who has given review

# %%
all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"}) ##.text not work for list
# Out:
# [<p class="_2sc7ZR _2V5EHH">Vamshi  Chakrala </p>]

# %%
all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Vamshi  Chakrala '

# %%
name=all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text

# %%
all_review[5].div.find_all('p',{"class":"_2-N8zT"})
# Out:
# [<p class="_2-N8zT">Worth every penny</p>]

# %%
all_review[5].div.find_all('p',{"class":"_2-N8zT"})[0].text
# Out:
# 'Worth every penny'

# %%
comment_header=all_review[5].div.find_all('p',{"class":"_2-N8zT"})[0].text

# %%
all_review[5].div.find_all('div',{"class":"t-ZTKy"})
# Out:
# [<div class="t-ZTKy"><div><div class="">Previously I was using one plus 3t it was a great phone <br/>And then I decided to upgrade I am stuck between Samsung s10 plus or iPhone 11 <br/>I have seen the specs and everything were good except the display it’s somewhere between 720-1080 and it’s not even an amoled it’s an LCD display <br/>But I decided to go with iPhone because I have never used an IOS device I have Been an android user from the past 9 years I ordered IPhone 11 (128gb) product red<br/>My experience after using 3 weeks <br/>1. The delivery ...</div><span class="_1BWGvX"><span>READ MORE</span></span></div></div>]

# %%
long_comment=all_review[5].div.find_all('div',{"class":"t-ZTKy"})[0].text

# %%
all_review[5].div.find_all('p',{"class":"_2sc7ZR"})
# Out:
# [<p class="_2sc7ZR _2V5EHH">Vamshi  Chakrala </p>,
#  <p class="_2sc7ZR">Jan, 2020</p>]

# %%
date_of_review=all_review[5].div.find_all('p',{"class":"_2sc7ZR"})[1].text

# %%
#lets find price

# %%
product3_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})
# Out:
# [<div class="_30jeq3 _16Jk6d">₹39,999</div>]

# %%
price=product3_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})[0].text

# %%
##lets for all reviews cretaed a loop

# %%
for i in all_review:
    name=i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
    rating=i.div.div.div.div.text
    comment_header=i.div.find_all('p',{"class":"_2-N8zT"})[0].text
    long_comment=i.div.find_all('div',{"class":"t-ZTKy"})[0].text
    date_of_review=i.div.find_all('p',{"class":"_2sc7ZR"})[1].text
    price=product3_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})[0].text
    print(name,'\t',rating,'\t',comment_header,'\t',long_comment,'\t',date_of_review,'\t',price)
    print("\n") # or u can do print()
# Out:
# Flipkart Customer 	 5 	 Simply awesome 	 Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.READ MORE 	 Nov, 2020 	 ₹39,999
#
#
# Flipkart Customer 	 5 	 Perfect product! 	 Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .READ MORE 	 Jun, 2020 	 ₹39,999
#
#
# Manish Raghuvanshi 	 5 	 Best in the market! 	 Great iPhone very snappy experience as apple kind. Upgraded from iPhone 7. Pros-Camera top class - Battery top performed -Chipset no need to say as apple kind -Security as you expect from apple - Display super bright industry leading colour   accuracy and super responsive -Build quality as expect from apple sturdy  premium durable beautiful stylish. -Os most stable os in smartphone industry Cons -No 5G-Display is not based on OLED technology -Charger headphones and 1 apple stic...READ MORE 	 Apr, 2021 	 ₹39,999
#
#
# ...

# %%
import mysql.connector as conn
mydb=conn.connect(host='localhost',user='root',passwd='Ritu@123')
cursor=mydb.cursor()
cursor.execute("create database if not exists review")
cursor.execute('create table if not exists review.storereview (name varchar(30),rating varchar(40),comment_header varchar(90),long_comment varchar(800)),date_of_review varchar(40)')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:565, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     564         query = query.encode("utf-8")
# --> 565     self._cmysql.query(
#     566         query,
#     567         raw=raw,
#     568         buffered=buffered,
#     569         raw_as_string=raw_as_string,
#     570         query_attrs=self._query_attrs,
#     571     )
#     572 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ',date_of_review varchar(40)' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ...
